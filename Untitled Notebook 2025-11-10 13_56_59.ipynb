# %%
# %sh
cd /Workspace/Repos/diksha.madan@altudo.co/krollpoc
GIT_CONFIG_GLOBAL=/dev/null GIT_CONFIG_SYSTEM=/dev/null git -c safe.directory=/Workspace/Repos/diksha.madan@altudo.co/krollpoc add .
git -c safe.directory=/Workspace/Repos/diksha.madan@altudo.co/krollpoc commit -m "Added dbt project"
git -c safe.directory=/Workspace/Repos/diksha.madan@altudo.co/krollpoc push

# %%
# %sh
cd /Workspace/Repos/diksha.madan@altudo.co/krollpoc
git config --local user.name "Diksha Madan"
git config --local user.email "diksha.madan@altudo.co"

# %%
# %sh
pwd
ls -a

# %%
# %sh
git config user.name "dikshamadan"
git config user.email "diksha.madan@altudo.co"

# %%
# %sh
git add .
git commit -m "Added dbt project files"
git push
